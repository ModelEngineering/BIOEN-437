# %% [markdown]
# # DIMENSION REDUCTION

# %% [markdown]
# # Preliminaries

# %%
# Python packages used in this chapter
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from sklearn.decomposition import PCA # type:ignore
from sklearn.preprocessing import StandardScaler # type:ignore
import urllib.request # use this library to download file from GitHub
try:
    import tellurium as te
except:
    # !pip install -q tellurium
    import tellurium as te
from typing import Optional, Union, List

# %%
LOCAL_MODEL_DIR = "/Users/jlheller/home/Technical/repos/SBMLModel/data"

# %% [markdown]
# # Helpers

# %%
def getLocalURL(url: Optional[str]=None, model_num: Optional[int]=None) -> Union[str, None]:
    """Finds the local file for a URL and returns the file contents.

    Args:
        url (str): The URL to convert.
            "https://www.ebi.ac.uk/biomodels/services/download/get-files/MODEL3352181362/3/BIOMD0000000206_url.xml"

    Returns:
        str: File contents
    """
    if url is not None:
        start_pos = url.index("BIOMD")
        if start_pos < 0:
            raise ValueError("URL does not contain 'BIOMD'")
        end_pos = url.index("_url")
        local_path = os.path.join(LOCAL_MODEL_DIR, f"BIOMD0{url[start_pos + 6:end_pos]}.xml")
    elif model_num is not None:
        local_path = os.path.join(LOCAL_MODEL_DIR, f"BIOMD{model_num:010d}.xml")
    else:
        raise ValueError("Either url or model_num must be provided.")
    if not os.path.exists(local_path):
        return None
    # Read the file contents
    with open(local_path, "r") as f:
        return f.read()

# TESTS
content = getLocalURL(model_num=298)
assert("xml" in content)
print("OK!")
# Out:
# OK!

# %% [markdown]
# # What & Why

# %% [markdown]
# <img src="dimension_reduction.png" alt="Description of image" width="1500" height="1500">

# %% [markdown]
# What is dimension reduction and why do I care?
# * Better visualization
# * Recognize conservation laws, which simplifies the chemical system

# %% [markdown]
# ## A simple example

# %%
model = """
A -> B; kf*A
B -> A; kb*B

A = 10
B = 0
kf = 1
kb = 0.5
"""
rr = te.loada(model)
data_arr = rr.simulate()
rr.plot()

# %% [markdown]
# This is really a one dimensional system. We see this since the sum of the two species is a constant.

# %%
df = pd.DataFrame(data_arr[:, 1:], columns=data_arr.colnames[1:])
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Glycolysis

# %%
np.std(df['[PYR]'])
# Out:
# 0.9994998749374607

# %%
URL = "https://www.ebi.ac.uk/biomodels/services/download/get-files/MODEL1009220000/2/MODEL1009220000_url.xml"
for ymax in [100, 10]:
    plt.figure()
    rr = te.loadSBMLModel(URL)
    data_arr = rr.simulate(0, 20, 1000)
    df = pd.DataFrame(data_arr[:, 1:], columns=data_arr.colnames[1:], index=data_arr[:, 0])
    df = df/df.std()
    df.plot(ylim=[0, ymax])

# %% [markdown]
# Observations
# * Chemical species have widely varying concentrations and so the data are in different units
# * Even so, many time courses look similar

# %% [markdown]
# # Principal Component Analysis for Computational Biology
# ## From Chemical Systems to Dimensionality Reduction
#
# ---
#
# **Biological insight:** These don't all vary independently
# - Early pathway metabolites often co-vary
# - ATP/ADP ratios coordinate multiple steps
# - Allosteric regulation creates coupled behaviors
#
# **Mathematical insight:** The 10-dimensional concentration space may be well-described by 2-3 "principal directions"
#
# ---
#
# ## From Time Series to Data Matrix
#
# Your simulation typically produces:
# ```
# Time    GLC   G6P   F6P   F1,6BP  DHAP  G3P   1,3BPG  3PG   2PG   PEP
# 0.0     10.0  0.1   0.05  0.01    0.01  0.01  0.001   0.1   0.05  0.02
# 0.1     9.8   0.3   0.15  0.03    0.02  0.02  0.003   0.12  0.06  0.03
# 0.2     9.5   0.5   0.25  0.06    0.04  0.04  0.006   0.15  0.08  0.04
# ...     ...   ...   ...   ...     ...   ...   ...     ...   ...   ...
# ```
#
# **PCA Question:** Can we find a few linear combinations of these 10 concentrations that capture most of the variation?
#
# ---
#
# ## The Data Matrix Setup
#
# **Data Matrix X:** Each row = one time point, each column = one species
# ```
# X = [x₁₁  x₁₂  ...  x₁₁₀]  ← Time point 1
#     [x₂₁  x₂₂  ...  x₂₁₀]  ← Time point 2
#     [ ⋮    ⋮   ⋱    ⋮  ]
#     [xₙ₁  xₙ₂  ...  xₙ₁₀]  ← Time point n
# ```
#
# **Dimensions:**
# - n time points (observations)
# - 19 molecular species (variables)
# - Want to reduce 19 dimensions to k << 19
#
# ---
#
# ## Biological Interpretation of Variance
#
# **High variance species:** Change dramatically over time
# - Often the "bottleneck" or rate-limiting enzymes
# - Key regulatory points
# - Species responding to perturbations
#
# **Low variance species:** Stay relatively constant
# - Often abundant cofactors (ATP, NADH)
# - Buffered intermediates
# - Downstream products in equilibrium
#
# **PCA insight:** Focus analysis on directions of maximal variance
#
# ---
#
# ## The Covariance Matrix - Biological Meaning
#
# **Covariance between species i and j:**
# ```
# Cov(X_i, X_j) = E[(X_i - μᵢ)(X_j - μⱼ)]
# ```
#
# **Biological interpretation:**
# - **Positive covariance:** Species increase/decrease together
#   - Same pathway, coordinated regulation
#   - Example: G6P and F6P in glycolysis
# - **Negative covariance:** Substrate-product relationships
#   - Example: Glucose vs. downstream metabolites
# - **Zero covariance:** Independent regulation
#
# ---
#
# ## Principal Components as Biological Modes
#
# **First Principal Component (PC1):**
# - Linear combination: PC1 = w₁₁×[Glu] + w₁₂×[G6P] + ... + w₁₁₀×[PEP]
# - Captures maximum variance across all time points
# - Often represents the "main flow" through the pathway
#
# **Second Principal Component (PC2):**
# - Orthogonal to PC1, captures second-most variance
# - Often represents regulatory perturbations or branch points
#
# **Biological analogy:** PCs are like the "fundamental modes" of pathway dynamics
#
# ---
#
# ## Mathematical Formulation
#
# **Goal:** Find orthogonal directions (principal components) that maximize variance
#
# **Solution:** Eigenvalue decomposition of covariance matrix C
# ```
# C × vᵢ = λᵢ × vᵢ
# ```
#
# Where:
# - **vᵢ** = eigenvector = principal component direction
# - **λᵢ** = eigenvalue = variance explained by PC i
# - **Ranking:** λ₁ ≥ λ₂ ≥ ... ≥ λ₁₀
#
# ---
#
# ## Interpreting Principal Component Loadings
#
# **PC loading for species j in component i = wᵢⱼ**
#
# **Large positive loading:** Species contributes strongly in same direction
# **Large negative loading:** Species contributes strongly in opposite direction
# **Small loading:** Species doesn't contribute much to this PC
#
# **Biological example:**
# - PC1 might have positive loadings for all glycolytic intermediates
# - PC2 might have positive loadings for early steps, negative for late steps
#
# ---
#
# ## Dimensionality Reduction Decision
#
# **How many PCs to keep?**
#
# 1. **Scree plot:** Plot eigenvalues, look for "elbow"
# 2. **Cumulative variance:** Keep PCs explaining 90-95% of variance
# 3. **Biological interpretation:** Stop when PCs become uninterpretable
#
# **Example:**
# - PC1: 65% variance (main pathway flux)
# - PC2: 20% variance (regulatory state)
# - PC3: 8% variance (noise/experimental error?)
# - Keep first 2 PCs → 85% variance with 80% fewer dimensions
#
# ---
#
# ## Practical Workflow for Biological Data
#
# 1. **Data preparation:**
#    - Center data (subtract mean concentrations)
#    - Consider scaling if species have very different concentration ranges
#
# 2. **Compute PCA:**
#    - Calculate covariance matrix
#    - Find eigenvectors and eigenvalues
#
# 3. **Biological interpretation:**
#    - Examine loadings for biochemical meaning
#    - Plot PC scores to visualize trajectory in reduced space
#
# 4. **Validation:**
#    - Check if PCs correspond to known pathway structure
#    - Test if reduced model captures perturbation responses
#
# ---
#
# ## Case Study - Circadian Clock
#
# **System:** 20 molecular species in mammalian circadian oscillator
#
# **Without PCA:** Track 20-dimensional dynamics, hard to visualize/understand
#
# **With PCA:**
# - PC1 (60% variance): Main oscillation (CLOCK/BMAL1 vs. PER/CRY)
# - PC2 (25% variance): Phase relationships between core and auxiliary loops
# - PC3 (10% variance): Response to light perturbations
#
# **Result:** 95% of dynamics captured in 3D instead of 20D
#
# ---
#
# ## When PCA Works Well in Biology
#
# **Good candidates:**
# - Metabolic pathways with linear sequences
# - Gene expression in developmental programs
# - Species with strong regulatory coupling
# - Systems with clear hierarchical organization
#
# **Poor candidates:**
# - Highly nonlinear dynamics (bistability, oscillations)
# - Systems with discrete state transitions
# - Species with multimodal distributions
# - Strong non-Gaussian noise
#
# ---
#
# ## Extensions and Alternatives
#
# **Dynamic PCA:** For time-varying systems
# **Sparse PCA:** When only few species should contribute to each PC
# **Kernel PCA:** For nonlinear relationships
# **Independent Component Analysis (ICA):** When components should be statistically independent
#
# **Biological context:** Different methods for different types of pathway organization
#
# ---
#
# ## Hands-On Exercise
#
# **Your turn!** Using your favorite pathway model:
#
# 1. Generate time series for multiple initial conditions
# 2. Arrange data as n×p matrix (timepoints × species)
# 3. Compute PCA using your preferred software
# 4. Interpret the first 2-3 components biologically
# 5. Plot the pathway trajectory in PC space
# 6. Compare reduced vs. full model predictions
#
# **Discussion:** Do the PCs make biological sense? How much variance is captured?
#
# ---
#
# ## Key Takeaways
#
# - **PCA formalizes biological intuition** about coordinated species behavior
# - **Eigenvectors represent fundamental modes** of pathway dynamics
# - **Dimensionality reduction** enables visualization and analysis of complex systems
# - **Biological interpretation** of PCs is crucial for meaningful insights
# - **PCA is a starting point** - consider nonlinear methods for complex dynamics
#
# **Next week:** We'll explore how PCA connects to metabolic control analysis and pathway sensitivity

# %% [markdown]
# # PCA in Practice

# %%
class PCAEncoderDecoder(object):
    
    def __init__(self, train_arr: np.ndarray, feature_names: Optional[List[str]]=None, num_reduced_dim:int=2,) -> None:
        self.num_reduced_dim = num_reduced_dim
        self.train_arr = train_arr
        self.num_feature = np.shape(train_arr)[1]
        if feature_names is None:
            feature_names = [str(n+1) for n in range(self.num_feature)]
        self.feature_names = feature_names
        self.scaler = StandardScaler()
        self.pca = PCA(n_components=self.num_reduced_dim, random_state=42)
        self.eigenval_arr = None
        self.encoded_arr = None
        self.encode()  # sets self.eigenval_arr, self.encoded_arr
        self.predicted_arr = self.decode(self.encoded_arr)
        self.eigenvector_arr = self.pca.components_
        
    def encode(self) -> None:
        # Encodes the training array into a lower dimension
        # Sets: self.eigenval_arr, self.encoded_arr
        cov_matrix = np.cov(self.train_arr.T)
        self.eigenval_arr, _ = np.linalg.eig(cov_matrix)
        #
        scaled_arr = self.scaler.fit_transform(self.train_arr)
        self.pca.fit(scaled_arr)
        self.encoded_arr = self.pca.transform(scaled_arr)
    
    def decode(self, encoded_arr: np.ndarray) -> np.ndarray:
        # Takes an array in the lower dimension back to the original dimension
        return self.scaler.inverse_transform(self.pca.inverse_transform(encoded_arr))
    
    @property
    def variance_explained(self) -> float:
        return np.sum(self.eigenval_arr[:self.num_reduced_dim])/np.sum(self.eigenval_arr)
    
    def plotPredictedVsActual(self) -> None:
        # Does plot for training array
        for idx in range(self.num_feature):
            plt.scatter(self.train_arr[:, idx], self.predicted_arr[:, idx])
        plt.xlabel("actual")
        plt.ylabel("predicted")
        plt.legend(self.feature_names)
        
    def plotPredictedVsTime(self, time_arr) -> None:
        # Plots time series of decoded
        _, axes = plt.subplots(1, 2, figsize=(15, 5))
        ylabels = ["actual", "predicted"]
        for plt_idx, arr in enumerate([self.train_arr, self.predicted_arr]):
            ax = axes[plt_idx]
            for idx in range(self.num_feature):
                ax.plot(time_arr, arr[:, idx])
            ax.set_xlabel("time")
            ax.set_ylabel(ylabels[plt_idx])
            ax.legend(self.feature_names)
            
    def plotEigenvectors(self) -> None:
        columns = [str(n+1) for n in range(self.num_reduced_dim)]
        value_arr = self.eigenvector_arr.T*self.eigenval_arr[0:self.num_reduced_dim]
        df = pd.DataFrame(value_arr.T, columns=self.feature_names)
        _ = df.plot(kind='bar', stacked=True)
        _ = plt.xlabel("eigenvector")
        _ = plt.ylabel("eigenvalue weighted coordinate")
        
    def plotPredicted(self) -> None:
        # Plots the first two dimensions of the predicted array
        plt.scatter(self.predicted_arr[:, 0], self.predicted_arr[:, 1])
        plt.text(self.predicted_arr[0, 0], self.predicted_arr[0, 1], "start")
        plt.text(self.predicted_arr[-1, 0], self.predicted_arr[-1, 1], "end")
        _ = plt.xlabel("first dimension")
        _ = plt.ylabel("second dimension")
        plt.title("First Two Dimensions in Reduced Space")
                                                        
    @classmethod
    def analyzeSimulation(cls, data_arr: np.ndarray, num_reduced_dim: int=2, offset: int=0) -> float:
        """
        Does plots for simulation output to assess a reduction in dimension.
        
        Args:
            data_arr: Output from tellurium simulation
            num_reduced_dim: reduced dimension
            offset: offset in data
            
        Returns:
            Variance explained
        """
        pca_encoder_decoder = PCAEncoderDecoder(data_arr[:, 1:], num_reduced_dim=num_reduced_dim,
                feature_names=data_arr.colnames[1:])
        pca_encoder_decoder.plotEigenvectors()
        plt.figure()
        pca_encoder_decoder.plotPredictedVsActual()
        plt.figure()
        pca_encoder_decoder.plotPredictedVsTime(data_arr[offset:, 0])
        plt.figure()
        pca_encoder_decoder.plotPredicted()
        #
        return pca_encoder_decoder.variance_explained
                
        

# TESTS
if False:
    result = PCAEncoderDecoder.analyzeSimulation(CIRCADIAN_ARR, num_reduced_dim=2)

n_components = 2
offset = 0
#
pca_encoder_decoder = PCAEncoderDecoder(CIRCADIAN_ARR[offset:, 1:], num_reduced_dim=n_components,
        feature_names=CIRCADIAN_ARR.colnames[1:])
assert(np.shape(pca_encoder_decoder.encoded_arr)[1] == n_components)
print("OK!")
# Out:
# OK!

# %%
result = PCAEncoderDecoder.analyzeSimulation(CIRCADIAN_ARR, num_reduced_dim=2)

# %%
result = PCAEncoderDecoder.analyzeSimulation(WOLF_ARR, num_reduced_dim=5)

# %%
offset = 0
pca_encoder_decoder = PCAEncoderDecoder(n_components=n_components)
encoded_arr = pca_encoder_decoder.encode(WOLF_ARR[offset:, 1:])
_ = plt.plot(WOLF_ARR[:, 0], pca_encoder_decoder.decode(encoded_arr))

# %% [markdown]
# ## Example 1: System with a constraint

# %% [markdown]
# ## Example 2: Functional dependent time courses

# %% [markdown]
# Plot Wolf in time in reduced space

# %% [markdown]
# # Principle Components Analysis (PCA)

# %% [markdown]
# # Autoencoders

# %% [markdown]
# # BACKUP

# %% [markdown]
# # Models

# %% [markdown]
# ## Circadian (298)

# %%
CIRCADIAN_MODEL = """
<?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<sbml xmlns="http://www.sbml.org/sbml/level2/version3" level="2" metaid="_18e897d1-a17d-4b1f-a290-a7f357a0b826" version="3">\n  <model id="Leloup1999_CircadianRhythms_Drosophila" metaid="metaid_0000002" name="Leloup1999_CircadianRhythms_Drosophila">\n    <notes>\n      <body xmlns="http://www.w3.org/1999/xhtml">\n        <p>\n      This a model from the article:\n      <br/>\n        <strong> Limit cycle models for circadian rhythms based on transcriptional regulation in Drosophila and Neurospora.\n</strong>\n        <br/>\nLeloup JC, Gonze D, Goldbeter A.\n      <em>J Biol Rhythms.</em>1999 Dec;14(6):433-48. \n      <a href="http://www.ncbi.nlm.nih.gov/pubmed/10643740">10643740</a>,\n      <br/>\n        <strong>Abstract:</strong>\n        <br/>\nWe examine theoretical models for circadian oscillations based on transcriptional regulation in Drosophila and Neurospora. For Drosophila, the molecular model is based on the negative feedback exerted on the expression of the per and tim genes by the complex formed between the PER and TIM proteins. For Neurospora, similarly, the model relies on the feedback exerted on the expression of the frq gene by its protein product FRQ. In both models, sustained rhythmic variations in protein and mRNA levels occur in continuous darkness, in the form of limit cycle oscillations. The effect of light on circadian rhythms is taken into account in the models by considering that it triggers degradation of the TIM protein in Drosophila, and frq transcription in Neurospora. When incorporating the control exerted by light at the molecular level, we show that the models can account for the entrainment of circadian rhythms by light-dark cycles and for the damping of the oscillations in constant light, though such damping occurs more readily in the Drosophila model. The models account for the phase shifts induced by light pulses and allow the construction of phase response curves. These compare well with experimental results obtained in Drosophila. The model for Drosophila shows that when applied at the appropriate phase, light pulses of appropriate duration and magnitude can permanently or transiently suppress circadian rhythmicity. We investigate the effects of the magnitude of light-induced changes on oscillatory behavior. Finally, we discuss the common and distinctive features of circadian oscillations in the two organisms.\n   </p>\n        <p> This particular version of the model has been translated from equations 1a-1j (Drosophila). </p>\n        <p>\nThis model was taken from the\n      <a href="http://www.cellml.org/models">CellML repository</a> and automatically converted to SBML.\n      <br/>\nThe original model was:\n      <a href="http://www.cellml.org/models/leloup_gonze_goldbeter_1999_version02">\n          <strong>Leloup JC, Gonze D, Goldbeter A. (1999) - version02</strong>\n        </a>\n        <br/>\nThe original CellML model was created by:\n      <br/>\n        <strong>Lloyd, Catherine, May</strong>\n        <br/>\nc.lloyd@aukland.ac.nz\n      <br/>\nThe University of Auckland\n      <br/>\nThe Bioengineering Institute\n      <br/></p>\n        <p>This model originates from BioModels Database: A Database of Annotated Published Models (http://www.ebi.ac.uk/biomodels/). It is copyright (c) 2005-2011 The BioModels.net Team.<br/>\nFor more information see the <a href="http://www.ebi.ac.uk/biomodels/legal.html" target="_blank">terms of use</a>.<br/>\nTo cite BioModels Database, please use: <a href="http://www.ncbi.nlm.nih.gov/pubmed/20587024" target="_blank">Li C, Donizelli M, Rodriguez N, Dharuri H, Endler L, Chelliah V, Li L, He E, Henry A, Stefan MI, Snoep JL, Hucka M, Le Novère N, Laibe C (2010) BioModels Database: An enhanced, curated and annotated resource for published quantitative kinetic models. BMC Syst Biol., 4:92.</a>\n      </p>\n    </body>\n  </notes>\n    <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n        <rdf:Description rdf:about="#metaid_0000002">\n\t<dc:creator>\n\t<rdf:Bag>\n\t<rdf:li rdf:parseType="Resource">\n\t<vCard:N rdf:parseType="Resource">\n\t<vCard:Family>Lloyd</vCard:Family>\n\t<vCard:Given>Catherine</vCard:Given>\n\t</vCard:N>\n\t<vCard:EMAIL>c.lloyd@auckland.ac.nz</vCard:EMAIL>\n\t<vCard:ORG rdf:parseType="Resource">\n\t<vCard:Orgname>University of Auckland</vCard:Orgname>\n\t</vCard:ORG>\n\t</rdf:li>\n\t<rdf:li rdf:parseType="Resource">\n\t<vCard:N rdf:parseType="Resource">\n\t<vCard:Family>Chelliah</vCard:Family>\n\t<vCard:Given>Vijayalakshmi</vCard:Given>\n\t</vCard:N>\n\t<vCard:EMAIL>viji@ebi.ac.uk</vCard:EMAIL>\n\t<vCard:ORG rdf:parseType="Resource">\n\t<vCard:Orgname>EMBL-EBI</vCard:Orgname>\n\t</vCard:ORG>\n\t</rdf:li>\n\t</rdf:Bag>\n\t</dc:creator>\n\t<dcterms:created rdf:parseType="Resource">\n\t<dcterms:W3CDTF>2009-04-28T15:31:24Z</dcterms:W3CDTF>\n\t</dcterms:created>\n\t<dcterms:modified rdf:parseType="Resource">\n\t<dcterms:W3CDTF>2015-02-25T13:41:24Z</dcterms:W3CDTF>\n\t</dcterms:modified>\n\t<bqmodel:is>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/biomodels.db/MODEL0478965170"/>\n\t</rdf:Bag>\n\t</bqmodel:is>\n\t<bqmodel:is>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/biomodels.db/BIOMD0000000298"/>\n\t</rdf:Bag>\n\t</bqmodel:is>\n\t<bqmodel:isDescribedBy>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/pubmed/10643740"/>\n\t</rdf:Bag>\n\t</bqmodel:isDescribedBy>\n\t<bqmodel:isDerivedFrom>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/biomodels.db/BIOMD0000000171"/>\n\t</rdf:Bag>\n\t</bqmodel:isDerivedFrom>\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/go/GO:0042752"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t<bqbiol:hasTaxon>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/taxonomy/7227"/>\n\t</rdf:Bag>\n\t</bqbiol:hasTaxon>\n\t<bqbiol:isPartOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.pathway/dme04710"/>\n\t</rdf:Bag>\n\t</bqbiol:isPartOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n      <listOfCompartments>\n      <compartment id="Compartment" metaid="_083401" size="1"/>\n    </listOfCompartments>\n    <listOfSpecies>\n      <species compartment="Compartment" id="MP" initialConcentration="0.0614368" metaid="_083424" name="MP" sboTerm="SBO:0000278">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083424">\n              <bqbiol:encodes>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t</rdf:Bag>\n\t</bqbiol:encodes>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:33699"/>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C02100"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="CN" initialConcentration="1.34728" metaid="_083474" name="CN" sboTerm="SBO:0000296">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083474">\n\t<bqbiol:hasPart>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t</rdf:Bag>\n\t</bqbiol:hasPart>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="C" initialConcentration="0.207614" metaid="_083470" name="C" sboTerm="SBO:0000296">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083470">\n\t<bqbiol:hasPart>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t</rdf:Bag>\n\t</bqbiol:hasPart>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="T2" initialConcentration="0.0145428" metaid="_083464" name="T2" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083464">\n              <bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00562"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="T1" initialConcentration="0.0213384" metaid="_083462" name="T1" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083462">\n              <bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00562"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="T0" initialConcentration="0.0217261" metaid="_083458" name="T0" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083458">\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="MT" initialConcentration="0.0860342" metaid="_083448" name="MT" sboTerm="SBO:0000278">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083448">\n              <bqbiol:encodes>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P49021"/>\n\t</rdf:Bag>\n\t</bqbiol:encodes>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:33699"/>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C02100"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="P0" initialConcentration="0.0169928" metaid="_083434" name="P0" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083434">\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="P1" initialConcentration="0.0141356" metaid="_083438" name="P1" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083438">\n              <bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00562"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n      <species compartment="Compartment" id="P2" initialConcentration="0.0614368" metaid="_083440" name="P2" sboTerm="SBO:0000245">\n        <annotation>\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqmodel="http://biomodels.net/model-qualifiers/" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">\n            <rdf:Description rdf:about="#_083440">\n              <bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/uniprot/P07663"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t\n\t<bqbiol:isVersionOf>\n\t<rdf:Bag>\n\t<rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00562"/>\n\t</rdf:Bag>\n\t</bqbiol:isVersionOf>\n\t</rdf:Description>\n\t\n\t</rdf:RDF>\n\t</annotation>\n            </species>\n    </listOfSpecies>\n    <listOfParameters>\n      <parameter id="vsP" metaid="_083426" name="vsP" sboTerm="SBO:0000186" value="1.1"/>\n      <parameter id="vmP" metaid="_083428" name="vmP" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="KmP" metaid="_083430" name="KmP" sboTerm="SBO:0000027" value="0.2"/>\n      <parameter id="KIP" metaid="_083432" name="KIP" sboTerm="SBO:0000009" value="1"/>\n      <parameter constant="false" id="Pt" metaid="_083446" name="Pt" sboTerm="SBO:0000360"/>\n      <parameter id="ksP" metaid="_083436" name="ksP" sboTerm="SBO:0000022" value="0.9"/>\n      <parameter id="vdP" metaid="_083442" name="vdP" sboTerm="SBO:0000186" value="2.2"/>\n      <parameter id="KdP" metaid="_083444" name="KdP" sboTerm="SBO:0000027" value="0.2"/>\n      <parameter id="vsT" metaid="_083450" name="vsT" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="vmT" metaid="_083452" name="vmT" sboTerm="SBO:0000186" value="0.7"/>\n      <parameter id="KmT" metaid="_083454" name="KmT" sboTerm="SBO:0000027" value="0.2"/>\n      <parameter id="KIT" metaid="_083456" name="KIT" sboTerm="SBO:0000009" value="1"/>\n      <parameter id="ksT" metaid="_083460" name="ksT" sboTerm="SBO:0000022" value="0.9"/>\n      <parameter id="vdT" metaid="_083466" name="vdT" sboTerm="SBO:0000186" value="3"/>\n      <parameter id="KdT" metaid="_083468" name="KdT" sboTerm="SBO:0000027" value="0.2"/>\n      <parameter id="kdC" metaid="_083472" name="kdC" sboTerm="SBO:0000356" value="0.01"/>\n      <parameter id="kdN" metaid="_083476" name="kdN" sboTerm="SBO:0000356" value="0.01"/>\n      <parameter id="k1" metaid="_083478" name="k1" sboTerm="SBO:0000022" value="0.8"/>\n      <parameter id="k2" metaid="_083480" name="k2" sboTerm="SBO:0000022" value="0.2"/>\n      <parameter id="k3" metaid="_083482" name="k3" sboTerm="SBO:0000153" value="1.2"/>\n      <parameter id="k4" metaid="_083484" name="k4" sboTerm="SBO:0000156" value="0.6"/>\n      <parameter id="kd" metaid="_083486" name="kd" sboTerm="SBO:0000356" value="0.01"/>\n      <parameter id="V1P" metaid="_083488" name="V1P" sboTerm="SBO:0000186" value="8"/>\n      <parameter id="V1T" metaid="_083490" name="V1T" sboTerm="SBO:0000186" value="8"/>\n      <parameter id="V2P" metaid="_083492" name="V2P" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="V2T" metaid="_083494" name="V2T" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="V3P" metaid="_083496" name="V3P" sboTerm="SBO:0000186" value="8"/>\n      <parameter id="V3T" metaid="_083498" name="V3T" sboTerm="SBO:0000186" value="8"/>\n      <parameter id="V4P" metaid="_083500" name="V4P" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="V4T" metaid="_083502" name="V4T" sboTerm="SBO:0000186" value="1"/>\n      <parameter id="K1P" metaid="_083504" name="K1P" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K1T" metaid="_083506" name="K1T" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K2P" metaid="_083508" name="K2P" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K2T" metaid="_083510" name="K2T" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K3P" metaid="_083512" name="K3P" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K3T" metaid="_083514" name="K3T" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K4P" metaid="_083516" name="K4P" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="K4T" metaid="_083518" name="K4T" sboTerm="SBO:0000027" value="2"/>\n      <parameter id="n" metaid="_083520" name="n" sboTerm="SBO:0000190" value="4"/>\n    </listOfParameters>\n    <listOfRules>\n      <rateRule metaid="_083403" variable="MP">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <times/>\n              <ci> vsP </ci>\n              <apply>\n                <divide/>\n                <apply>\n                  <power/>\n                  <ci> KIP </ci>\n                  <ci> n </ci>\n                </apply>\n                <apply>\n                  <plus/>\n                  <apply>\n                    <power/>\n                    <ci> KIP </ci>\n                    <ci> n </ci>\n                  </apply>\n                  <apply>\n                    <power/>\n                    <ci> CN </ci>\n                    <ci> n </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> vmP </ci>\n                <apply>\n                  <divide/>\n                  <ci> MP </ci>\n                  <apply>\n                    <plus/>\n                    <ci> KmP </ci>\n                    <ci> MP </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> MP </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083405" variable="P0">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> ksP </ci>\n                <ci> MP </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V2P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K2P </ci>\n                    <ci> P1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V1P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P0 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K1P </ci>\n                    <ci> P0 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> P0 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083407" variable="P1">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V1P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P0 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K1P </ci>\n                    <ci> P0 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V4P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K4P </ci>\n                    <ci> P2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V2P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K2P </ci>\n                    <ci> P1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V3P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K3P </ci>\n                    <ci> P1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> P1 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083409" variable="P2">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V3P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K3P </ci>\n                    <ci> P1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k4 </ci>\n                <ci> C </ci>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V4P </ci>\n                <apply>\n                  <divide/>\n                  <ci> P2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K4P </ci>\n                    <ci> P2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k3 </ci>\n                <ci> P2 </ci>\n                <ci> T2 </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> vdP </ci>\n                <apply>\n                  <divide/>\n                  <ci> P2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> KdP </ci>\n                    <ci> P2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> P2 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083411" variable="MT">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <times/>\n              <ci> vsT </ci>\n              <apply>\n                <divide/>\n                <apply>\n                  <power/>\n                  <ci> KIT </ci>\n                  <ci> n </ci>\n                </apply>\n                <apply>\n                  <plus/>\n                  <apply>\n                    <power/>\n                    <ci> KIT </ci>\n                    <ci> n </ci>\n                  </apply>\n                  <apply>\n                    <power/>\n                    <ci> CN </ci>\n                    <ci> n </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> vmT </ci>\n                <apply>\n                  <divide/>\n                  <ci> MT </ci>\n                  <apply>\n                    <plus/>\n                    <ci> KmT </ci>\n                    <ci> MT </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> MT </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083413" variable="T0">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> ksT </ci>\n                <ci> MT </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V2T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K2T </ci>\n                    <ci> T1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V1T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T0 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K1T </ci>\n                    <ci> T0 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> T0 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083415" variable="T1">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V1T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T0 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K1T </ci>\n                    <ci> T0 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V4T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K4T </ci>\n                    <ci> T2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V2T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K2T </ci>\n                    <ci> T1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> V3T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K3T </ci>\n                    <ci> T1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> T1 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083417" variable="T2">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V3T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T1 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K3T </ci>\n                    <ci> T1 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k4 </ci>\n                <ci> C </ci>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> V4T </ci>\n                <apply>\n                  <divide/>\n                  <ci> T2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> K4T </ci>\n                    <ci> T2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k3 </ci>\n                <ci> P2 </ci>\n                <ci> T2 </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> vdT </ci>\n                <apply>\n                  <divide/>\n                  <ci> T2 </ci>\n                  <apply>\n                    <plus/>\n                    <ci> KdT </ci>\n                    <ci> T2 </ci>\n                  </apply>\n                </apply>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kd </ci>\n                <ci> T2 </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083419" variable="C">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> k3 </ci>\n                <ci> P2 </ci>\n                <ci> T2 </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k2 </ci>\n                <ci> CN </ci>\n              </apply>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> k4 </ci>\n                <ci> C </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> k1 </ci>\n                <ci> C </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kdC </ci>\n                <ci> C </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <rateRule metaid="_083421" variable="CN">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <minus/>\n            <apply>\n              <times/>\n              <ci> k1 </ci>\n              <ci> C </ci>\n            </apply>\n            <apply>\n              <plus/>\n              <apply>\n                <times/>\n                <ci> k2 </ci>\n                <ci> CN </ci>\n              </apply>\n              <apply>\n                <times/>\n                <ci> kdN </ci>\n                <ci> CN </ci>\n              </apply>\n            </apply>\n          </apply>\n        </math>\n            </rateRule>\n      <assignmentRule metaid="_083423" variable="Pt">\n        <math xmlns="http://www.w3.org/1998/Math/MathML">        \n          <apply>\n            <plus/>\n            <ci> P0 </ci>\n            <ci> P1 </ci>\n            <ci> P2 </ci>\n            <ci> C </ci>\n            <ci> CN </ci>\n          </apply>\n        </math>\n            </assignmentRule>\n    </listOfRules>\n  </model>\n</sbml>\n
"""

# %%
rr = te.loadSBMLModel(CIRCADIAN_MODEL)
CIRCADIAN_ARR = rr.simulate(0, 10, 1000)
rr.plot()

# %% [markdown]
# ## Wolf

# %%
WOLF_MODEL = """
// Created by libAntimony v2.12.0
model *Jana_WolfGlycolysis()

  // Compartments and Species:
  compartment compartment_;
  species Glucose in compartment_, fructose_1_6_bisphosphate in compartment_;
  species glyceraldehyde_3_phosphate in compartment_, glycerate_3_phosphate in compartment_;
  species pyruvate in compartment_, Acetyladehyde in compartment_, External_acetaldehyde in compartment_;
  species ATP in compartment_, ADP in compartment_, NAD in compartment_, NADH in compartment_;
  species $External_glucose in compartment_, $ethanol in compartment_, $Glycerol in compartment_;
  species $Sink in compartment_;

  // Reactions:
  J0: $External_glucose => Glucose; J0_inputFlux;
  J1: Glucose + 2 ATP => fructose_1_6_bisphosphate + 2 ADP; J1_k1*Glucose*ATP*(1/(1 + (ATP/J1_Ki)^J1_n));
  J2: fructose_1_6_bisphosphate => glyceraldehyde_3_phosphate + glyceraldehyde_3_phosphate; J2_k*fructose_1_6_bisphosphate;
  J3: glyceraldehyde_3_phosphate + NADH => NAD + $Glycerol; J3_k*glyceraldehyde_3_phosphate*NADH;
  J4: glyceraldehyde_3_phosphate + ADP + NAD => ATP + glycerate_3_phosphate + NADH; (J4_kg*J4_kp*glyceraldehyde_3_phosphate*NAD*ADP - J4_ka*J4_kk*glycerate_3_phosphate*ATP*NADH)/(J4_ka*NADH + J4_kp*ADP);
  J5: glycerate_3_phosphate + ADP => ATP + pyruvate; J5_k*glycerate_3_phosphate*ADP;
  J6: pyruvate => Acetyladehyde; J6_k*pyruvate;
  J7: Acetyladehyde + NADH => NAD + $ethanol; J7_k*Acetyladehyde*NADH;
  J8: Acetyladehyde => External_acetaldehyde; J8_k1*Acetyladehyde - J8_k2*External_acetaldehyde;
  J9: ATP => ADP; J9_k*ATP;
  J10: External_acetaldehyde => $Sink; J10_k*External_acetaldehyde;

  // Species initializations:
  Glucose = 0;
  fructose_1_6_bisphosphate = 0;
  glyceraldehyde_3_phosphate = 0;
  glycerate_3_phosphate = 0;
  pyruvate = 0;
  Acetyladehyde = 0;
  External_acetaldehyde = 0;
  ATP = 3;
  ADP = 1;
  NAD = 0.5;
  NADH = 0.5;
  External_glucose = 0;
  ethanol = 0;
  Glycerol = 0;
  Sink = 0;
  // Compartment initializations:
  compartment_ = 1;

  // Variable initializations:
  J0_inputFlux = 50;
  J1_k1 = 550;
  J1_Ki = 1;
  J1_n = 4;
  J2_k = 9.8;
  J3_k = 85.7;
  J4_kg = 323.8;
  J4_kp = 76411.1;
  J4_ka = 57823.1;
  J4_kk = 23.7;
  J5_k = 80;
  J6_k = 9.7;
  J7_k = 2000;
  J8_k1 = 375;
  J8_k2 = 375;
  J9_k = 28;
  J10_k = 80;

  // Other declarations:
  const compartment_, J0_inputFlux, J1_k1, J1_Ki, J1_n, J2_k, J3_k, J4_kg;
  const J4_kp, J4_ka, J4_kk, J5_k, J6_k, J7_k, J8_k1, J8_k2, J9_k, J10_k;
end
"""

# %%
rr = te.loada(WOLF_MODEL)
WOLF_ARR = rr.simulate(0, 10, 400)
rr.plot()

# %%
np.shape(WOLF_ARR)
# Out:
# (400, 12)
